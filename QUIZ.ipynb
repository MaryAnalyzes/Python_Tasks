# %%
# Creating dictionary for quiz question
question={'que1:What is the capital of Nigeria?','Option:A.lagos B.Abuja C.Oyo','answer:B'},
question2={"que2:How many local government is in Nigeria","answer:774"},
question3={'que3:what is 5*9','answer:45'},
question4={'que4:who is the richest man on earth','Option:A.Elon Musk B.Tutor Grace B.Wealth'},
question5={'que5: what is 4-1','answer:3'},
question6={'que6:Who is the president of Nigeria','option:A.Nimi Adegbite B.Bola Ahmed Tinubu C.Davido','answer:B'},
question7={'que7:What is 3(5)-4(2)','answer:7'},
question8={'que8:How many days make a leap year?','answer:366'},
questin9={'que9:How many seconds make a minute','anwer:60'},
question10={'que10:what is 4*4','answer:16'}

# %%
# Print a welcome message
def greet(Name):
  return 'Hello, '+Name+'! Welcome to the quiz'

# %%
greet('Wealth')
# Out:
# 'Hello, Wealth! Welcome to the quiz'

# %%
#initiale score
score=0

# %%
while True:
  question=input('que1:What is the capital of Nigeria?,  Option:A.lagos B.Abuja C.Oyo, answer=')
  if question.upper()=='B':
    print('Correct')
    score+=1
  else:
    print('Incorrect')


  question=input('que2:How many local government is in Nigeria","answer answer=')
  if question.upper()=='774':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que3:what is 5*9,answer:')
  if question.upper()=='45':
    print ('correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que4:who is the richest man on earth,  Option:A.Elon Musk B.Tutor Grace B.Wealth')
  if question.upper()=='A':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que5: what is 4-1,   answer=')
  if question.upper()=='3':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que6:Who is the president of Nigeria, option:A.Nimi Adegbite B.Bola Ahmed Tinubu C.Davido,  answer=')
  if question.upper()=='B':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que7:What is 3(5)-4(2),answer:')
  if question.upper()=='7':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que8:How many days make a leap year?,  answer:')
  if question.upper()=='366':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que9:How many seconds make a minute,  anwer:')
  if question.upper()=='60':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  question=input('que10:what is 4*4, answer:')
  if question.upper()=='16':
    print('Correct')
    score+=1
  else:
    print('Incorrect')

  what_to_do_next=input('What do you want to do next? Retry/skip/quit')
  if what_to_do_next.upper()=='Retry':
    continue
  else:
    print('your score is, {score}')
    break
# Out:
# que1:What is the capital of Nigeria?,  Option:A.lagos B.Abuja C.Oyo, answer=a
# Incorrect
# que2:How many local government is in Nigeria","answer answer=774
# Correct
# que3:what is 5*9,answer:45
# correct
# que4:who is the richest man on earth,  Option:A.Elon Musk B.Tutor Grace B.Wealtha
# Correct
# que5: what is 4-1,   answer=2
# Incorrect
# que6:Who is the president of Nigeria, option:A.Nimi Adegbite B.Bola Ahmed Tinubu C.Davido,  answer=b
# Correct
# que7:What is 3(5)-4(2),answer:7
# Correct
# que8:How many days make a leap year?,  answer:366
# Correct
# que9:How many seconds make a minute,  anwer:60
# Correct
# que10:what is 4*4, answer:16
# Correct
# What do you want to do next? Retry/skip/quitquit
# your score is, {score}
